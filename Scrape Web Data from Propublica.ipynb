# %% [markdown]
# ## Get connections of Judicial Watch

# %%
import requests
from bs4 import BeautifulSoup
import time

# Base URL for ProPublica's nonprofit search results
base_url = "https://projects.propublica.org/nonprofits/full_text_search"

# Number of pages to scrape (increase if needed)
num_pages = 14  # You can adjust this as needed

# Search query parameter
search_query = "52-1885088"

# A list to hold all company information
company_info_list = []

# Loop through each page and scrape the company information
for page_num in range(1, num_pages + 1):
    # Build the URL for the specific page
    page_url = f"{base_url}?page={page_num}&q={search_query}"

    # Fetch the page content
    response = requests.get(page_url)
    response.raise_for_status()  # Ensure successful request

    # Parse the HTML content
    soup = BeautifulSoup(response.text, "html.parser")

    # Find all elements containing company names
    company_elements = soup.find_all("div", class_="form-name text-link result-item__hed margin-right")

    # Extract the text (company name, form type, year) from each element
    for elem in company_elements:
        raw_text = elem.find("a").get_text(strip=True)

        # Split the raw text to get relevant parts
        parts = raw_text.split('—')

        # Get the company name
        company_name = parts[0].strip()

        # Get the form details
        form_info = parts[1].strip() if len(parts) > 1 else ""

        # Determine the relationship and extract the year
        if "Schedule I" in form_info:
            relationship = "Grant"
        elif "Schedule A" in form_info:
            relationship = "Supported Company"
        else:
            relationship = "Unknown"

        # Extract the year from the form information
        year_part = form_info.split("(")[-1].strip(")")
        year = int(year_part) if year_part.isdigit() else "Unknown"

        # Create a dictionary to store the company's details
        company_info = {
            "Company Name": company_name,
            "Relationship": relationship,
            "Year": year,
        }
        
        print(company_info)

        # Add the company info to the list
        company_info_list.append(company_info)
    
    time.sleep(10)  # Pause for 10 seconds before scraping the next page

# Output all collected company information
# for info in company_info_list:
#     print(f"Company Name: {info['Company Name']}")
#     print(f"Relationship: {info['Relationship']}")
#     print(f"Year: {info['Year']}")
#     print("----")
# Out:
# {'Company Name': 'Citizens For Home Rule Inc', 'Relationship': 'Grant', 'Year': 2023}
# {'Company Name': 'Phoenix Law Enforcement Association', 'Relationship': 'Grant', 'Year': 2017}
# {'Company Name': 'The Halaj Foundation', 'Relationship': 'Supported Company', 'Year': 2013}
# {'Company Name': 'Leadership Institute', 'Relationship': 'Grant', 'Year': 2019}
# {'Company Name': 'Center Of The American Experiment', 'Relationship': 'Grant', 'Year': 2022}
# {'Company Name': 'Center Of The American Experiment', 'Relationship': 'Grant', 'Year': 2021}
# {'Company Name': 'National Center For Housing Management', 'Relationship': 'Grant', 'Year': 2018}
# {'Company Name': 'Center Of The American Experiment', 'Relationship': 'Grant', 'Year': 2020}
# {'Company Name': 'Community Foundation Donor Directed Fund', 'Relationship': 'Grant', 'Year': 2018}
# {'Company Name': 'Kauai Energy Institute', 'Relationship': 'Grant', 'Year': 2020}
# {'Company Name': 'Capital Community Foundation Inc', 'Relationship': 'Grant', 'Year': 2022}
# {'Company Name': 'Kauai Energy Institute', 'Relationship': 'Grant', 'Year': 2021}
# {'Company Name': 'Kauai Energy Institute', 'Relationship': 'Grant', 'Year': 2022}
# {'Company Name': 'Ramtell Inc', 'Relationship': 'Supported Company', 'Year': 2015}
# {'Company Name': 'The Helen Diller Family Foundation', 'Relationship': 'Grant', 'Year': 2018}
# {'Company Name': 'Ramtell Inc', 'Relationship': 'Supported Company', 'Year': 2013}
# {'Company Name': 'The Jewish Federation Of Sarasota Manatee Inc', 'Relationship': 'Grant', 'Year': 2022}
# {'Company Name': 'Judicial Watch Inc', 'Relationship': 'Unknown', 'Year': 2019}
# {'Company Name': 'Judicial Watch Inc', 'Relationship': 'Unknown', 'Year': 2013}
# {'Company Name': 'Judicial Watch Inc', 'Relationship': 'Unknown', 'Year': 2018}
# {'Company Name': 'Judicial Watch Inc', 'Relationship': 'Unknown', 'Year': 2016}
# {'Company Name': 'Judicial Watch Inc', 'Relationship': 'Unknown', 'Year': 2015}
# {'Company Name': 'Judicial Watch Inc', 'Relationship': 'Unknown', 'Year': 2022}
# {'Company Name': 'Judicial Watch Inc', 'Relationship': 'Unknown', 'Year': 2021}
# {'Company Name': 'Judicial Watch Inc', 'Relationship': 'Unknown', 'Year': 2014}
# {'Company Name': 'Judicial Watch Inc', 'Relationship': 'Unknown', 'Year': 2020}
# {'Company Name': 'Judicial Watch Inc', 'Relationship': 'Unknown', 'Year': 2022}
# {'Company Name': 'Judicial Watch Inc', 'Relationship': 'Unknown', 'Year': 2017}
# {'Company Name': 'The American Foundation For Charitable Support Inc', 'Relationship': 'Supported Company', 'Year': 2016}
# {'Company Name': 'The Jewish Federation Of Sarasota Manatee Inc', 'Relationship': 'Grant', 'Year': 2016}
# {'Company Name': 'The Jewish Federation Of Sarasota Manatee Inc', 'Relationship': 'Grant', 'Year': 2018}
# {'Company Name': 'The Helen Diller Family Foundation', 'Relationship': 'Grant', 'Year': 2017}
# {'Company Name': 'The Jewish Federation Of Sarasota Manatee Inc', 'Relationship': 'Grant', 'Year': 2020}
# {'Company Name': 'Community Foundation Of North Florida Inc', 'Relationship': 'Grant', 'Year': 2019}
# {'Company Name': 'The Jewish Federation Of Sarasota Manatee Inc', 'Relationship': 'Grant', 'Year': 2017}
# {'Company Name': 'The American Foundation For Charitable Support Inc', 'Relationship': 'Supported Company', 'Year': 2020}
# {'Company Name': 'The Greater Pinebelt Community Foundation', 'Relationship': 'Grant', 'Year': 2022}
# {'Company Name': 
 'Relationship': 'Grant', 'Year': 2020}
# {'Company Name': 'Morgan Stanley Global Impact Funding Trust Inc', 'Relationship': 'Grant', 'Year': 2020}
# {'Company Name': 'National Philanthropic Trust', 'Relationship': 'Grant', 'Year': 2020}
# {'Company Name': 'National Christian Charitable Foundation Inc', 'Relationship': 'Grant', 'Year': 2019}
# {'Company Name': 'Columbus Foundation', 'Relationship': 'Grant', 'Year': 2015}
# {'Company Name': 'American Endowment Foundation', 'Relationship': 'Grant', 'Year': 2021}
# {'Company Name': 'National Christian Charitable Foundation Inc', 'Relationship': 'Grant', 'Year': 2020}
# {'Company Name': 'Network For Good Inc', 'Relationship': 'Grant', 'Year': 2018}
# {'Company Name': 'American Endowment Foundation', 'Relationship': 'Grant', 'Year': 2016}
# {'Company Name': 'National Philanthropic Trust', 'Relationship': 'Grant', 'Year': 2021}
# {'Company Name': 'National Christian Charitable Foundation Inc', 'Relationship': 'Grant', 'Year': 2021}
# {'Company Name': 'National Christian Charitable Foundation Inc', 'Relationship': 'Grant', 'Year': 2022}
# {'Company Name': 'National Christian Charitable Foundation Inc', 'Relationship': 'Grant', 'Year': 2022}
# {'Company Name': 'Network For Good Inc', 'Relationship': 'Grant', 'Year': 2019}
# {'Company Name': 'Network For Good Inc', 'Relationship': 'Grant', 'Year': 2021}
# {'Company Name': 'National Philanthropic Trust', 'Relationship': 'Grant', 'Year': 2022}
# {'Company Name': 'American Endowment Foundation', 'Relationship': 'Grant', 'Year': 2022}
# {'Company Name': 'The Blackbaud Giving Fund', 'Relationship': 'Grant', 'Year': 2022}
# {'Company Name': 'Network For Good Inc', 'Relationship': 'Grant', 'Year': 2020}
# {'Company Name': 'National Christian Charitable Foundation Inc', 'Relationship': 'Grant', 'Year': 2014}
# {'Company Name': 'Schwab Charitable Fund', 'Relationship': 'Grant', 'Year': 2015}
# {'Company Name': 'Schwab Charitable Fund', 'Relationship': 'Grant', 'Year': 2016}
# {'Company Name': 'National Christian Charitable Foundation Inc', 'Relationship': 'Grant', 'Year': 2015}
# {'Company Name': 'Schwab Charitable Fund', 'Relationship': 'Grant', 'Year': 2017}
# {'Company Name': 'Vanguard Charitable Endowment Program', 'Relationship': 'Grant', 'Year': 2021}
# {'Company Name': 'National Christian Charitable Foundation Inc', 'Relationship': 'Grant', 'Year': 2016}
# {'Company Name': 'National Christian Charitable Foundation Inc', 'Relationship': 'Grant', 'Year': 2018}
# {'Company Name': 'National Christian Charitable Foundation Inc', 'Relationship': 'Grant', 'Year': 2017}
# {'Company Name': 'Vanguard Charitable Endowment Program', 'Relationship': 'Grant', 'Year': 2022}
# {'Company Name': 'Schwab Charitable Fund', 'Relationship': 'Grant', 'Year': 2018}
# {'Company Name': 'American Online Giving Foundation Inc', 'Relationship': 'Grant', 'Year': 2020}
# {'Company Name': 'Schwab Charitable Fund', 'Relationship': 'Grant', 'Year': 2019}
# {'Company Name': 'Schwab Charitable Fund', 'Relationship': 'Grant', 'Year': 2020}
# {'Company Name': 'American Online Giving Foundation Inc', 'Relationship': 'Grant', 'Year': 2021}
# {'Company Name': 'American Online Giving Foundation Inc', 'Relationship': 'Grant', 'Year': 2022}
# {'Company Name': 'American Online Giving Foundation Inc', 'Relationship': 'Grant', 'Year': 2023}
# {'Company Name': 'Fidelity Investments Charitable Gift Fund', 'Relationship': 'Grant', 'Year': 2018}
# {'Company Name': 'Schwab Charitable Fund', 'Relationship': 'Grant', 'Year': 2022}
# {'Company Name': 'Fidelity Investments Charitable Gift Fund', 'Relationship': 'Grant', 'Year': 2017}
# {'Company Name': 'Schwab Charitable Fund', 'Relationship': 'Grant', 'Year': 2021}
# {'Company Name': 'Fidelity Investments Charitable Gift Fund', 'Relationship': 'Grant', 'Year': 2019}
# {'Company Name': 'Fidelity Investments Charitable Gift Fund', 'Relationship': 'Grant', 'Year': 2020}
# {'Company Name': 'Fidelity Investments Charitable Gift Fund', 'Relationship': 'Grant', 'Year': 2021}
# {'Company Name': 'Fidelity Investments Charitable Gift Fund', 'Relationship': 'Grant', 'Year': 2022}
# {'Company Name': 'Fidelity Investments Charitable Gift Fund', 'Relationship': 'Grant', 'Year': 2022}

# %%
unique_companies = set()
filtered_data = []

for entry in company_info_list:
    company_name = entry['Company Name']
    relationship = entry['Relationship']
    
    # Ignore entries with 'Unknown' relationship
    if relationship.lower() == 'unknown':
        continue
    
    # If the company name is unique, add it to the set and filtered data
    if company_name not in unique_companies:
        unique_companies.add(company_name)
        filtered_data.append({
            'Company Name': company_name,
            'Relationship': relationship
        })

filtered_data
# Out:
# [{'Company Name': 'Citizens For Home Rule Inc', 'Relationship': 'Grant'},
#  {'Company Name': 'Phoenix Law Enforcement Association',
#   'Relationship': 'Grant'},
#  {'Company Name': 'The Halaj Foundation', 'Relationship': 'Supported'},
#  {'Company Name': 'Leadership Institute', 'Relationship': 'Grant'},
#  {'Company Name': 'Center Of The American Experiment',
#   'Relationship': 'Grant'},
#  {'Company Name': 'National Center For Housing Management',
#   'Relationship': 'Grant'},
#  {'Company Name': 'Community Foundation Donor Directed Fund',
#   'Relationship': 'Grant'},
#  {'Company Name': 'Kauai Energy Institute', 'Relationship': 'Grant'},
#  {'Company Name': 'Capital Community Foundation Inc', 'Relationship': 'Grant'},
#  {'Company Name': 'Ramtell Inc', 'Relationship': 'Supported'},
#  {'Company Name': 'The Helen Diller Family Foundation',
#   'Relationship': 'Grant'},
#  {'Company Name': 'The Jewish Federation Of Sarasota Manatee Inc',
#   'Relationship': 'Grant'},
#  {'Company Name': 'The American Foundation For Charitable Support Inc',
#   'Relationship': 'Supported'},
#  {'Company Name': 'Community Foundation Of North Florida Inc',
#   'Relationship': 'Grant'},
#  {'Company Name': 'The Greater Pinebelt Community Foundation',
#   'Relationship': 'Grant'},
#  {'Company Name': 'Community Foundation For Nantucket',
#   'Relationship': 'Grant'},
#  {'Company Name': 'Family Office Foundation Incorporated',
#   'Relationship': 'Grant'},
#  {'Company Name': 'Wiseheart Foundation', 'Relationship': 'Grant'},
#  {'Company Name': 'Greene County Community Foundation',
#   'Relationship': 'Grant'},
#  {'Company Name': 'Cornell University Foundation', 'Relationship': 'Grant'},
#  {'Company Name': 'Oregon Jewish Community Foundation',
#   'Relationship': 'Grant'},
#  {'Company Name': 'Bradley Impact Fund Inc', 'Relationship': 'Grant'},
#  {'Company Name': 'The Community Foundation Of The Texas Hill Country Inc',
#   'Relationship': 'Grant'},
#  {'Company Name': 'Richland County Foundation Of Mansfield',
#   'Relationship': 'Grant'},
#  {'Company Name': 'East Texas Communties Foundation Inc',
#   'Relationship': 'Grant'},
#  {'Company Name': 'Southwest Florida Community Foundation Inc',
#   'Relationship': 'Grant'},
#  {'Company Name': 'Community Foundation Of Collier County',
#   'Relationship': 'Grant'},
#  {'Company Name': 'Rancho Santa Fe Foundation', 'Relationship': 'Grant'},
#  {'Company Name': 'Quad Cities Community Foundation', 'Relationship': 'Grant'},
#  {'Company Name': 'Essex County Community Foundation Incorporated',
#   'Relationship': 'Grant'},
#  {'Company Name': 'Pasadena Community Foundation', 'Relationship': 'Grant'},
#  {'Company Name': 'Sonoma County Community Foundation',
#   'Relationship': 'Grant'},
#  {'Company Name': 'The Parasol Tahoe Community Foundation Inc',
#   'Relationship': 'Grant'},
#  {'Company Name': 'Community Foundation Of North Texas',
#   'Relationship': 'Grant'},
#  {'Company Name': '
#  'Community Foundation Donor Directed Fund',
#  'Kauai Energy Institute',
#  'Capital Community Foundation Inc',
#  'Ramtell Inc',
#  'The Helen Diller Family Foundation',
#  'The Jewish Federation Of Sarasota Manatee Inc',
#  'The American Foundation For Charitable Support Inc',
#  'Community Foundation Of North Florida Inc',
#  'The Greater Pinebelt Community Foundation',
#  'Community Foundation For Nantucket',
#  'Family Office Foundation Incorporated',
#  'Wiseheart Foundation',
#  'Greene County Community Foundation',
#  'Cornell University Foundation',
#  'Oregon Jewish Community Foundation',
#  'Bradley Impact Fund Inc',
#  'The Community Foundation Of The Texas Hill Country Inc',
#  'Richland County Foundation Of Mansfield',
#  'East Texas Communties Foundation Inc',
#  'Southwest Florida Community Foundation Inc',
#  'Community Foundation Of Collier County',
#  'Rancho Santa Fe Foundation',
#  'Quad Cities Community Foundation',
#  'Essex County Community Foundation Incorporated',
#  'Pasadena Community Foundation',
#  'Sonoma County Community Foundation',
#  'The Parasol Tahoe Community Foundation Inc',
#  'Community Foundation Of North Texas',
#  'Communitygiving',
#  'Community Foundation Of Jackson Hole',
#  'Gulf Coast Community Foundation Inc',
#  'Christian Community Foundation Of Memphis And The Mid South Inc',
#  'The Community Foundation Of Greater Birmingham',
#  'Dayton Foundation',
#  'Santa Barbara Foundation',
#  'Donors Trust Inc',
#  'Amg Charitable Gift Foundation',
#  'Community Foundation Of Sarasota County Inc',
#  'North Carolina Community Foundation Inc',
#  'Ernst & Young Foundation',
#  'Give Lively Foundation Inc',
#  'St Louis Community Foundation Incorporated',
#  'Dallas Foundation A Tx Nonprofit Corporation',
#  'Greater Houston Community Foundation',
#  'Greater Horizons',
#  'Community Foundation Of Greater Memphis Inc',
#  'Christian Community Foundation Inc',
#  'Jewish Community Fdn Of The Jewish Federation Council Of Greater La',
#  'The Greater New Orleans Foundation',
#  'Rochester Area Community Foundation',
#  'Arizona Community Foundation',
#  'Alaska Community Foundation',
#  'Pittsburgh Foundation',
#  'Jewish Community Federation Of S F Marin Peninsula & Sonoma Counties',
#  'Greater Kansas City Community Foundation',
#  'Combined Jewish Philanthropies Of Greater Boston Inc',
#  'The Community Foundation For Greater Atlanta Inc',
#  'American Gift Fund',
#  'Greater Washington Community Foundation',
#  'Bny Mellon Charitable Gift Fund',
#  'Community Foundation Of New Jersey',
#  'Greater Cincinnati Foundation',
#  'Servant Foundation',
#  'Denver Foundation',
#  'The Bessemer Giving Fund',
#  'Minneapolis Foundation',
#  'Chattanooga Christian Community Foundation',
#  'Columbus Foundation',
#  'Saint Paul & Minnesota Foundation',
#  'Tulsa Community Foundation',
#  'California Community Foundation',
#  'Oregon Community Foundation',
#  'Morgan Stanley Global Impact Funding Trust Inc',
#  'T Rowe Price Program For Charitable Giving Inc',
#  'Silicon Valley Community Foundation',
#  'Jewish Communal Fund',
#  'Raymond James Charitable Endowment Fund',
#  'The Chicago Community Trust',
#  'Goldman Sachs Philanthropy Fund',
#  'Communities Foundation Of Texas',
#  'United Way Worldwide',
#  'Charities Aid Foundation America',
#  'Ayco Charitable Foundation',
#  'National Philanthropic Trust',
#  'American Endowment Foundation',
#  'National Christian Charitable Foundation Inc',
#  'Paypal Charitable Giving Fund',
#  'Network For Good Inc',
#  'The Blackbaud Giving Fund',
#  'Schwab Charitable Fund',
#  'Vanguard Charitable Endowment Program',
#  'American Online Giving Foundation Inc',
#  'Fidelity Investments Charitable Gift Fund']

# %% [markdown]
# ## Get EIN number of companies

# %%
# Base endpoint for the ProPublica Nonprofit Explorer API
base_url = "https://projects.propublica.org/nonprofits/api/v2/search.json"

# Dictionary to store company names and their EINs
company_eins = {}

for name in company_names:
    # Construct the request URL with the company name
    response = requests.get(f"{base_url}?q={name}")
    
    if response.status_code == 200:
        data = response.json()
        # Check if there are organizations in the response
        if 'organizations' in data and data['organizations']:
            # Get the EIN from the first organization in the results
            ein = data['organizations'][0]['ein']
            company_eins[name] = ein
        else:
            company_eins[name] = "EIN not found"
    else:
        company_eins[name] = "Error in API request"

print(company_eins)
# Out:
# {'Citizens For Home Rule Inc': 621113012, 'Phoenix Law Enforcement Association': 510189787, 'The Halaj Foundation': 954700852, 'Leadership Institute': 510235174, 'Center Of The American Experiment': 363611426, 'National Center For Housing Management': 520955650, 'Community Foundation Donor Directed Fund': 830313321, 'Kauai Energy Institute': 274346053, 'Capital Community Foundation Inc': 561942969, 'Ramtell Inc': 351925455, 'The Helen Diller Family Foundation': 311655715, 'The Jewish Federation Of Sarasota Manatee Inc': 591227747, 'The American Foundation For Charitable Support Inc': 860857725, 'Community Foundation Of North Florida Inc': 593473384, 'The Greater Pinebelt Community Foundation': 721390352, 'Community Foundation For Nantucket': 134316755, 'Family Office Foundation Incorporated': 472788229, 'Wiseheart Foundation': 455085493, 'Greene County Community Foundation': 311751001, 'Cornell University Foundation': 222848738, 'Oregon Jewish Community Foundation': 931019725, 'Bradley Impact Fund Inc': 454678325, 'The Community Foundation Of The Texas Hill Country Inc': 742225369, 'Richland County Foundation Of Mansfield': 340872883, 'East Texas Communties Foundation Inc': 752309138, 'Southwest Florida Community Foundation Inc': 596580974, 'Community Foundation Of Collier County': 592396243, 'Rancho Santa Fe Foundation': 953709639, 'Quad Cities Community Foundation': 426122716, 'Essex County Community Foundation Incorporated': 43407816, 'Pasadena Community Foundation': 200253310, 'Sonoma County Community Foundation': 680003212, 'The Parasol Tahoe Community Foundation Inc': 880362053, 'Community Foundation Of North Texas': 752267767, 'Communitygiving': 363412544, 'Community Foundation Of Jackson Hole': 830308856, 'Gulf Coast Community Foundation Inc': 591052433, 'Christian Community Foundation Of Memphis And The Mid South Inc': 621752885, 'The Community Foundation Of Greater Birmingham': 631209631, 'Dayton Foundation': 316027287, 'Santa Barbara Foundation': 951866094, 'Donors Trust Inc': 522166327, 'Amg Charitable Gift Foundation': 841260437, 'Community Foundation Of Sarasota County Inc': 591956886, 'North Carolina Community Foundation Inc': 581661700, 'Ernst & Young Foundation': 136094489, 'Give Lively Foundation Inc': 810693451, 'St Louis Community Foundation Incorporated': 431758789, 'Dallas Foundation A Tx Nonprofit Corporation': 752890371, 'Greater Houston Community Foundation': 237160400, 'Greater Horizons': 200849590, 'Community Foundation Of Greater Memphis Inc': 581723645, 'Christian Community Foundation Inc': 751750059, 'Jewish Community Fdn Of The Jewish Federation Council Of Greater La': 956111928, 'The Greater New Orleans Foundation': 720408921, 'Rochester Area Community Foundation': 237250641, 'Arizona Community Foundation': 860348306, 'Alaska Community Foundation': 920155067, 'Pittsburgh Foundation': 250965466, 'Jewish Community Federation Of S F Marin Peninsula & Sonoma Counties': 941156533, 'Greater Kansas City Community Foundation': 431152398, 'Combined Jewish Philanthropies Of Greater Boston Inc': 42103559, 'The Community Foundation For Greater Atlanta Inc': 581344646, 'American Gift Fund': 516506426, 'Greater Washington Community Foundation': 237343119, 'Bny Mellon Charitable Gift Fund': 300748315, 'Community Foundation Of New Jersey': 222281783, 'Greater Cincinnati Foundation': 310669700, 'Servant Foundation': 464802386, 'Denver Foundation': 846048381, 'The Bessemer Giving Fund': 137111099, 'Minneapolis Foundation': 416029402, 'Chattanooga Christian Community Foundation': 621536731, 'Columbus Foundation': 316044264, 'Saint Paul & Minnesota Foundation': 300729624, 'Tulsa Community Foundation': 731554474, 'California Community Foundation': 953510055, 'Oregon Community Foundation': 237315673, 'Morgan Stanley Global Impact Funding Trust Inc': 527082731, 'T Rowe Price Program For Charitable Giving Inc': 311709466, 'Silicon Valley Community Foundation': 205205488, 'Jewish Communal Fund': 237174183, 'Raymond Jame ...

# %% [markdown]
# ## Get level 2 connections

# %%
import requests
from bs4 import BeautifulSoup
import time
import random

# Base URL for ProPublica's nonprofit search results
base_url = "https://projects.propublica.org/nonprofits/full_text_search"

# Pause between requests (in seconds) to avoid rate limiting
scrape_delay = 30.01

# Maximum number of pages to attempt scraping
max_pages = 15


def get_company_connections(search_query, max_pages=15):
    """
    Scrapes the ProPublica Nonprofit Explorer for connections related to a specific EIN or company name.
    Filters the results to ensure unique company names and exclude 'Unknown' relationships.

    Args:
    - search_query (str): The EIN or company name to search for.
    - max_pages (int): Maximum number of pages to scrape for connections.

    Returns:
    - List[dict]: A list of unique dictionaries with filtered connection details.
    """
    company_info_list = []
    unique_companies = set()

    for page_num in range(1, max_pages + 1):
        
        # Pause before scraping the next page
        time.sleep(scrape_delay + random.uniform(0, 1))
        
        # Build the URL for the specific page
        page_url = f"{base_url}?page={page_num}&q={search_query}"

        # Fetch the page content and handle 404 error
        response = requests.get(page_url)
        
        if response.status_code == 404:
            break  # Exit the loop if the page does not exist
        elif not response.ok:
            # Log error and continue to the next page
            print(f"Error fetching page {page_num} for {search_query}: {response.status_code}")
            break

        response.raise_for_status()  # Ensure successful request

        # Parse the HTML content
        soup = BeautifulSoup(response.text, "html.parser")

        # Find all elements containing company names
        company_elements = soup.find_all("div", class_="form-name text-link result-item__hed margin-right")

        # If no elements are found, assume we've reached the end
        if not company_elements:
            break
        
        # Extract the text (company name, form type, year) from each element
        for elem in company_elements:
            raw_text = elem.find("a").get_text(strip=True)

            # Split the raw text to get relevant parts
            parts = raw_text.split('—')

            # Get the company name
            company_name = parts[0].strip()

            # Get the form details
            form_info = parts[1].strip() if len(parts) > 1 else ""

            # Determine the relationship and extract the year
            if "Schedule I" in form_info:
                relationship = "Grant"
            elif "Schedule A" in form_info:
                relationship = "Supported Company"
            else:
                relationship = "Unknown"

            # If the relationship is 'Unknown', skip it
            if relationship.lower() == 'unknown':
                continue

            # Add unique company names to set and filtered data
            if company_name not in unique_companies:
                unique_companies.add(company_name)
                
                # Extract the year from the form information
                year_part = form_info.split("(")[-1].strip(")")
                year = int(year_part) if year_part.isdigit() else "Unknown"
                
                # Add the filtered data to the list
                company_info_list.append({
                    'Company Name': company_name,
                    'Relationship': relationship,
                    'Year': year,
                })
                
                print(company_name, relationship, year)

    return company_info_list


# Define the list of company names (previously obtained)
company_names = list(company_eins.values())

# Dictionary to store all company connections
all_connections = {}

# Get connections for each company in the list
for i, company_name in enumerate(company_names):
    connections = get_company_connections(company_name, max_pages=max_pages)  # Fetch connections for the company
    all_connections[list(company_eins.keys())[i]] = connections  # Store the connections in the dictionary

# Display all connections for each company
for company_name, connections in all_connections.items():
    print(f"Connections for {company_name}:")
    for connection in connections:
        print(f"  - {connection['Company Name']} (Relationship: {connection['Relationship']}, Year: {connection['Year']})")
    print("\n")
# Out:
# The William A And Genevieve H Strong Foundation Tr Supported Company 2022
# Leadership Exchange Academy Inc Grant 2016
# American Future Fund Grant 2015
# Kenosha Community Foundation Grant 2021
# Donors Capital Fund Inc Supported Company 2020
# Ramtell Inc Supported Company 2015
# Charles Koch Institute Grant 2016
# The American Foundation For Charitable Support Inc Supported Company 2016
# Horizon Community Funds Of Northern Kentucky Inc Grant 2019
# Hutchinson Community Foundation Grant Unknown
# Bradley Impact Fund Inc Grant 2015
# Community Foundation For Mississippi Grant Unknown
# Community Foundation Of Abilene Grant 2016
# Community Foundation Of Southwest Louisiana Grant 2022
# Community Foundation Of The Eastern Shore Inc Grant 2021
# Cornell University Foundation Grant 2022
# University Impact Grant 2022
# Richland County Foundation Of Mansfield Grant 2021
# Southwest Florida Community Foundation Inc Grant 2021
# Community Foundation Of Herkimer And Oneida Counties Inc Grant 2021
# Rancho Santa Fe Foundation Grant 2019
# Community Foundation Of Greater Dubuque Grant 2018
# Jewish Federation Of Palm Beach County Inc Grant 2021
# Community Foundation Of Broward Inc Grant 2022
# The Community Foundation Of Louisville Inc Grant Unknown
# Greater Salina Community Foundation Grant 2023
# Community Foundation Of Tampa Bay Inc Grant 2014
# Pasadena Community Foundation Grant 2021
# South Dakota Community Foundation Grant 2022
# Community Foundation Of Jackson Hole Grant 2020
# Associated Jewish Charities Of Baltimore Grant 2018
# Greater Horizons Grant 2015
# Christian Community Foundation Of Memphis And The Mid South Inc Grant 2021
# Catholic Community Foundation Of Minnesota Grant 2020
# The Community Foundatio Of Louisville Depository Inc Grant 2022
# Donors Trust Inc Grant 2022
# Community Foundation Of The Ozarks Inc Grant 2022
# Ernst & Young Foundation Grant 2018
# Community Foundation Of North Texas Grant 2016
# Sacramento Region Community Foundation Grant 2020
# Dallas Foundation A Tx Nonprofit Corporation Grant 2019
# Austin Community Foundation Grant 2018
# Pittsburgh Foundation Grant 2015
# Community Foundation Of Greater Memphis Inc Grant 2023
# St Louis Community Foundation Incorporated Grant 2019
# Orange County Community Foundation Grant 2022
# Greater Cincinnati Foundation Grant Unknown
# Cleveland Foundation Grant 2018
#   - The Bessemer Giving Fund (Relationship: Grant, Year: 2022)
#   - Mightycause Charitable Foundation (Relationship: Grant, Year: Unknown)
#   - The Us Charitable Gift Trust (Relationship: Grant, Year: Unknown)
#   - Goldman Sachs Philanthropy Fund (Relationship: Grant, Year: 2017)
#   - Morgan Stanley Global Impact Funding Trust Inc (Relationship: Grant, Year: 2019)
#   - National Philanthropic Trust (Relationship: Grant, Year: 2015)
#   - Paypal Charitable Giving Fund (Relationship: Grant, Year: 2022)
#   - National Christian Charitable Foundation Inc (Relationship: Grant, Year: Unknown)
#   - American Endowment Foundation (Relationship: Grant, Year: 2021)
#   - Schwab Charitable Fund (Relationship: Grant, Year: 2015)
#   - Vanguard Charitable Endowment Program (Relationship: Grant, Year: 2021)
#   - Fidelity Investments Charitable Gift Fund (Relationship: Grant, Year: 2017)
#
#
# Connections for National Center For Housing Management:
#
#
# Connections for Community Foundation Donor Directed Fund:
#
#
# Connections for Kauai Energy Institute:
#
#
# Connections for Capital Community Foundation Inc:
#   - Capital Community Foundation Inc (Relationship: Grant, Year: 2016)
#   - Schwab Charitable Fund (Relationship: Grant, Year: 2022)
#
#
# Connections for Ramtell Inc:
#
#
# Connections for The Helen Diller Family Foundation:
#   - Tri Valley Socks (Relationship: Grant, Year: 2022)
#   - Jewish Community Federation Of S F Marin Peninsula & Sonoma Counties (Relationship: Grant, Year: 2021)
#
#
# Connections for The Jewish Federation Of Sarasota Manatee Inc:
#
#
# Connections for The American Foundation For Charitable Support Inc:
#
#
# Connections for Community Foundation Of North Florida Inc:
#
#
# Connections for The Greater Pinebelt Community Foundation:
#
#
# Connections for Community Foundation For Nantucket:
#
#
# Connections for Family Office Foundation Incorporated:
#
#
# Connections for Wiseheart Foundation:
#
#
# Connections for Greene County Community Foundation:
#
#
# Connections for Cornell University Foundation:
#
#
# Connections for Oregon Jewish Community Foundation:
#
#
# Connections for Bradley Impact Fund Inc:
#
#
# Connections for The Community Foundation Of The Texas Hill Country Inc:
#
#
# Connections for Richland County Foundation Of Mansfield:
#
#
# Connections for East Texas Communties Foundation Inc:
#
#
# Connections for Southwest Florida Community Foundation Inc:
#
#
# Connections for Community Foundation Of Collier County:
#
#
# Connections for Rancho Santa Fe Foundation:
#
#
# Connections for Quad Cities Community Foundation:
#
#
# Connections for Essex County Community Foundation Incorporated:
#
#
# Connections for Pasadena Community Foundation:
#
#
# Connections for Sonoma County Community Foundation:
#
#
# Connections for The Parasol Tahoe Community Foundation Inc:
#
#
# Connections for Community Foundation Of North Texas:
#
#
# Connections for Communitygiving:
#
#
# Connections for Community Foundation Of Jackson Hole:
#
#
# Connections for Gulf Coast Community Foundation Inc:
#
#
# Connections for Christian Community Foundation Of Memphis And The Mid South Inc:
#
#
# Connections for The Community Foundation Of Greater Birmingham:
#
#
# Connections for Dayton Foundation:
#
#
# Connections for Santa Barbara Foundation:
#
#
# Connections for Donors Trust Inc:
#
#
# Connections for Amg Charitable Gift Foundation:
#
#
# Connections for Community Foundation Of Sarasota County Inc:
#
#
# Connections for North Carolina Community Foundation Inc:
#
#
# Connections for Ernst & Young Foundation:
#
#
# Connections for Give Lively Foundation Inc:
#
#
# Connections for St Louis Community Foundation Incorporated:
#
#
# Connections for Dallas Foundation A Tx Nonprofit Corporation:
#
#
# Connections for Greater Houston Community Foundation:
#
#
# Connections for Greater Horizons:
#
#
# Connections for Community Foundation Of Greater Memphis Inc:
#
#
# Connections for Christian Community Foundation Inc:
#
#
# Connections for Jewish Community Fdn Of The Jewish Federation Council Of Greater La:
#
#
# Connections for The Greater New Orleans Foundation:
#
#
# Connections for Rochester Area Community Foundation:
#
#
# Connections for Arizona Community Foundation:
#
#
# Connections for Alaska Community Foundation:
#
#
# Connections for Pittsburgh Foundation:
#
#
# Connections for Jewish Community Federation Of S F Marin Peninsula & Sonoma Counties:
#
#
# Connections for Greater Kansas City Community Foundation:
#
#
# Connections for Combined Jewish Philanthropies Of Greater Boston Inc:
#
#
# Connections for The Community Foundation For Greater Atlanta Inc:
#
#
# Connections for American Gift Fund:
#
#
# Connections for Greater Washington Community Foundation:
#
#
# Connections for Bny Mellon Charitable Gift Fund:
#
#
# Connections for Community Foundation Of New Jersey:
#
#
# Connections for Greater Cincinnati Foundation:
#
#
# Connections for Servant Foundation:
#
#
# Connections for Denver Foundation:
#
#
# Connections for The Bessemer Giving Fund:
#
#
# Connections for Minneapolis Foundation:
#
#
# Connections for Chattanooga Christian Community Foundation:
#
#
# Connections for Columbus Foundation:
#
#
# Connections for Saint Paul & Minnesota Foundation:
#
#
# Connections for Tulsa Community Foundation:
#
#
# Connections for California Community Foundation:
#
#
# Connections for Oregon Community Foundation:
#
#
# Connections for Morgan Stanley Global Impact Funding Trust Inc:
#
#
# Connections for T Rowe Price Program For Charitable Giving Inc:
#
#
# Connections for Silicon Valley Community Foundation:
#
#
# Connections for Jewish Communal Fund:
#
#
# Connections for Raymond James Charitable Endowment Fund:
#
#
# Connections for The Chicago Community Trust:
#
#
# Connections for Goldman Sachs Philanthropy Fund:
#
#
# Connections for Communities Foundation Of Texas:
#
#
# Connections for United Way Worldwide:
#
#
# Connections for Charities Aid Foundation America:
#
#
# Connections for Ayco Charitable Foundation:
#
#
# Connections for National Philanthropic Trust:
#
#
# Connections for American Endowment Foundation:
#
#
# Connections for National Christian Charitable Foundation Inc:
#
#
# Connections for Paypal Charitable Giving Fund:
#
#
# Connections for Network For Good Inc:
#
#
# Connections for The Blackbaud Giving Fund:
#
#
# Connections for Schwab Charitable Fund:
#
#
# Connections for Vanguard Charitable Endowment Program:
#
#
# Connections for American Online Giving Foundation Inc:
#
#
# Connections for Fidelity Investments Charitable Gift Fund:

# %%
import csv

# Storing the filtered connections in a CSV file
csv_file_path = "company_connections_3.csv"

with open(csv_file_path, mode="w", newline="", encoding="utf-8") as csv_file:
    csv_writer = csv.writer(csv_file)

    # Write the header row
    csv_writer.writerow(["Company Name", "Connection Name", "Relationship", "Year"])

    # Write data for each company and its connections
    for company_name, connections in all_connections.items():
        for connection in connections:
            csv_writer.writerow([
                company_name,
                connection["Company Name"],
                connection["Relationship"],
                connection["Year"],
            ])

print(f"Filtered data saved to CSV file: {csv_file_path}")
# Out:
# Filtered data saved to CSV file: company_connections_3.csv
